# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-CarlosAlbertoNievesPerez/blob/main/Semana_4_Data_Analysis_with_Python_(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![2022-10-10 20_06_52-DA0101EN Progress _ Cognitive Class.png](data:image/png;base64,...)

# %% [markdown]
# #INTRODUCTION TO DATA ANLYSIS WITH PYTHON

# %% [markdown]
# ##Intro y puntos a recordar

# %% [markdown]
# We have divided the Python data analysis libraries into three groups: The first group is called
# "scientific computing libraries." Pandas offers data structure and tools for
# effective data manipulation and analysis.
# It provides fast access to structured data.
# The primary instrument of Pandas is a two-dimensional table consisting of column and row labels,
# which are called a DataFrame.
# It is designed to provide easy indexing functionality.
#
# The Numpy library uses arrays for its inputs and outputs.
# It can be extended to objects for matrices, and with minor coding changes, developers
# can perform fast array processing.
#
# SciPy includes functions for some advanced math problems, as listed on this slide, as
# well as data visualization.
#
# The Matplotlib package is the most well-known library for data visualization.
# It is great for making graphs and plots.
#
# Another high-level visualization library is Seaborn.
# It is based on Matplotlib.
# It's very easy to generate various plots such as heat maps, time series, and violin
# plots.
#
# The Scikit-learn library contains tools for
# statistical modeling, including regression, classification, clustering and so on.
# This library is built on NumPy, SciPy and Matplotlib.
#
# StatsModels is also a Python module that allows users to explore data, estimate statistical
# models, and perform statistical tests.

# %% [markdown]
# recuerda que:
#
#       -df prints the entire data frame
#
#       -df.head(n) shows the firs n rows of data frame
#
#       -df.tail(n) shows the bottom n ros of data frames
#
#
# tambien es importante que revises el csv file. Si este tiene titulos en las columnas importalo tal cual, pero si no tiene lo tendrias que poner de la siguiente forma:
#
#
#       -df=pd.read_csv(url, header=None)
#   Header=None le dice que no hay titulos en las columnas
#
#
#
# Cuando tengamos que usar header none, podemos ponerle titulos a los headers con el sigueinte codigo
#
#       -headers=["Marca", "Tipo de combustible", "# de puertas", etc...]
#       df.columns=headers

# %% [markdown]
# para exportar usas
# path= "link de windows donde quieras guardarlo"
#   -df.to_csv(path)

# %% [markdown]
# ![2022-10-10 19_52_03-Importing and Exporting Data in Python 4_13 _ Importing and Exporting Data in Py.png](data:image/png;base64,...)

# %% [markdown]
# ##Analisis de informacion en python

# %% [markdown]
# Para ver que tipo de data es la que se esta importando usas el siguiente codigo:
#
#
#       -df.types
#
# Para obtener un resumen estadisticos usamos el siguiente codigo:
#
#
#       -df.describe()
#
# Para obtener un full summary statistics usamos el siguiente codigo:
#
#       -df.describe(include="all")

# %%
 import pandas as pd
 import numpy as np
